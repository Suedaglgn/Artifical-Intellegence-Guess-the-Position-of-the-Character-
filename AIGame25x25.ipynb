# %% [markdown]
#  # <font color='black'>  Game Board and Movement Set </font>

# %%
import random
import csv
from csv import reader

# %% [markdown]
# ## <font color='black'> Distance and Direction Sets </font>

# %%
list_distance = [(1),(2),(3)]
list_direction = [(1),(2),(3),(4),(5),(6),(7),(8)]

# %% [markdown]
# ## <font color='black'> Generate Random Initial Position </font>

# %%
x = random.randint(0,25) # for 25x25 gameboard
y = random.randint(0,25)
initial_position = [(x),(y)]
C = 25*(y-1) + x
print(initial_position)
# Out:
# [11, 7]

# %% [markdown]
# ## <font color='black'> Generate Random Movement </font>

# %%
k=0
while (k<400000): # k is the total number of train and test steps
    distance = random.choice(list_distance)
    direction = random.choice(list_direction)
    cycle_position = [(x), (y)]
    cycle_C = C  
    if(direction==1):
        if(distance==1):
            X = x-1
            Y = y+1
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x-2
            Y = y+2
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x-3
            Y = y+3
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==2):
        if(distance==1):
            X = x
            Y = y+1
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x
            Y = y+2
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x
            Y = y+3
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==3):
        if(distance==1):
            X = x+1
            Y = y+1
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x+2
            Y = y+2
            C = 8
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x+3
            Y = y+3
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==4):
        if (distance==1):
            X = x+1
            Y = y
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x+2
            Y = y
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x+3
            Y = y
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==5):
        if(distance==1):
            X = x+1
            Y = y-1
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x+2
            Y = y-2
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x+3
            Y = y-3
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==6):
        if(distance==1):
            X = x
            Y = y-1
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x
            Y = y-2
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x
            Y = y-3
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==7):
        if(distance==1):
            X = x-1
            Y = y-1
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x-2
            Y = y-2
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x-3
            Y = y-3
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
    if(direction==8):
        if(distance==1):
            X = x-1
            Y = y
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==2):
            X = x-2
            Y = y
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        elif(distance==3):
            X = x-3
            Y = y
            if X>0 and X<26 and Y>0 and Y<26:
                x = X
                y = Y
                C = 25*(y-1) + x
        
    position = [cycle_C, direction, distance, C]
    k = k+1
    # Create Dataset
    with open('movements_400tho_25x25.csv', 'a', newline='') as file:
        writer = csv.writer(file)
        writer.writerow(position)
